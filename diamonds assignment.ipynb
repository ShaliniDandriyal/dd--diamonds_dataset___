# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv")
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data['clarity']
# Out:
# 0        SI2
# 1        SI1
# 2        VS1
# 3        VS2
# 4        SI2
#         ...
# 53935    SI1
# 53936    SI1
# 53937    SI1
# 53938    SI2
# 53939    SI2
# Name: clarity, Length: 53940, dtype: object

# %%
quality= data['color']

# %%
quality
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.select_dtypes('object')
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %%
data.rename(columns={"carat":"cat"},inplace=True)

# %%
data
# Out:
#         cat        cut color clarity  depth  table  price     x     y     z
# 0      0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4      0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935  0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936  0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937  0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938  0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939  0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.rename(columns={"carat":"cat","cut":"cute","color":"colors","depth":"deep","table":"tables","price":"prices","x":"xx","y":"yy","z":"zz"},inplace=True)
data
# Out:
#         cat       cute colors clarity  deep  tables  prices    xx    yy    zz
# 0      0.23      Ideal      E     SI2  61.5    55.0     326  3.95  3.98  2.43
# 1      0.21    Premium      E     SI1  59.8    61.0     326  3.89  3.84  2.31
# 2      0.23       Good      E     VS1  56.9    65.0     327  4.05  4.07  2.31
# 3      0.29    Premium      I     VS2  62.4    58.0     334  4.20  4.23  2.63
# 4      0.31       Good      J     SI2  63.3    58.0     335  4.34  4.35  2.75
# ...     ...        ...    ...     ...   ...     ...     ...   ...   ...   ...
# 53935  0.72      Ideal      D     SI1  60.8    57.0    2757  5.75  5.76  3.50
# 53936  0.72       Good      D     SI1  63.1    55.0    2757  5.69  5.75  3.61
# 53937  0.70  Very Good      D     SI1  62.8    60.0    2757  5.66  5.68  3.56
# 53938  0.86    Premium      H     SI2  61.0    58.0    2757  6.15  6.12  3.74
# 53939  0.75      Ideal      D     SI2  62.2    55.0    2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.rename(columns={"carat":"cat","depth":"deep"},inplace=True)
data
# Out:
#         cat       cute colors clarity  deep  tables  prices    xx    yy    zz
# 0      0.23      Ideal      E     SI2  61.5    55.0     326  3.95  3.98  2.43
# 1      0.21    Premium      E     SI1  59.8    61.0     326  3.89  3.84  2.31
# 2      0.23       Good      E     VS1  56.9    65.0     327  4.05  4.07  2.31
# 3      0.29    Premium      I     VS2  62.4    58.0     334  4.20  4.23  2.63
# 4      0.31       Good      J     SI2  63.3    58.0     335  4.34  4.35  2.75
# ...     ...        ...    ...     ...   ...     ...     ...   ...   ...   ...
# 53935  0.72      Ideal      D     SI1  60.8    57.0    2757  5.75  5.76  3.50
# 53936  0.72       Good      D     SI1  63.1    55.0    2757  5.69  5.75  3.61
# 53937  0.70  Very Good      D     SI1  62.8    60.0    2757  5.66  5.68  3.56
# 53938  0.86    Premium      H     SI2  61.0    58.0    2757  6.15  6.12  3.74
# 53939  0.75      Ideal      D     SI2  62.2    55.0    2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#8
coloumn_name={"cat":"carat","cute":"cut","colors":"color","clarity":"clear","deep":"depth","tables":"table","prices":"price","xx":"x","yy":"y","zz":"z"}
data.rename(columns=coloumn_name,inplace=True)

# %%
data
# Out:
#        carat        cut color clear  depth  table  price     x     y     z
# 0       0.23      Ideal     E   SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E   SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E   VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I   VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J   SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...   ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D   SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D   SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D   SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H   SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D   SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#9
data.drop(['color'],axis=1)
# Out:
#        carat        cut clear  depth  table  price     x     y     z
# 0       0.23      Ideal   SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium   SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good   VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium   VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good   SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal   SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good   SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good   SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium   SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal   SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
#10
data.drop(['color','clear','table'],axis=1)
# Out:
#        carat        cut  depth  price     x     y     z
# 0       0.23      Ideal   61.5    326  3.95  3.98  2.43
# 1       0.21    Premium   59.8    326  3.89  3.84  2.31
# 2       0.23       Good   56.9    327  4.05  4.07  2.31
# 3       0.29    Premium   62.4    334  4.20  4.23  2.63
# 4       0.31       Good   63.3    335  4.34  4.35  2.75
# ...      ...        ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal   60.8   2757  5.75  5.76  3.50
# 53936   0.72       Good   63.1   2757  5.69  5.75  3.61
# 53937   0.70  Very Good   62.8   2757  5.66  5.68  3.56
# 53938   0.86    Premium   61.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal   62.2   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
#11
data.drop([2,4])
# Out:
#        carat        cut color clear  depth  table  price     x     y     z
# 0       0.23      Ideal     E   SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E   SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I   VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.24  Very Good     J  VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I  VVS1   62.3   57.0    336  3.95  3.98  2.47
# ...      ...        ...   ...   ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D   SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D   SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D   SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H   SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D   SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53938 rows x 10 columns]

# %%
data=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv")
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#12
#pf=data.sort_values('cut')
pf=data.cut.sort_values(ascending=True)
pf
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %%
type(pf)
# Out:
# pandas.core.series.Series

# %%
#13
qf=data.price.sort_values(ascending=False)
qf
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53940, dtype: int64

# %%
type(qf)
# Out:
# pandas.core.series.Series

# %%
#14
data.sort_values("carat")
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]

# %%
data.sort_values("carat",ascending=False)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31601   0.20  Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
#
# [53940 rows x 10 columns]

# %%
#15
result_df=data[data['carat']>=0.3]
result_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 13      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 15      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16      0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [52341 rows x 10 columns]

# %%
#16
p=[1,3,6,8,10,24,55]
series=pd.Series(p)
series
# Out:
# 0     1
# 1     3
# 2     6
# 3     8
# 4    10
# 5    24
# 6    55
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
#17
#result_df=data[data['x']>=5 & data['y']>5 & data['z']>5]
result_df=data[(data.x>5) & (data.y>5) & (data.depth>5)]
result_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 90      0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 91      0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 92      0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 93      0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# 94      0.78  Very Good     G     SI2   63.8   56.0   2759  5.81  5.85  3.72
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [36196 rows x 10 columns]

# %%
#18
#result=data[(data.cut=='Premium') | (data.cut=='Ideal')]
result=data[data.cut.isin(['Premium','Ideal'])]
result
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]

# %%
#19
#result=data[(data.cut=='Good') | (data.cut=='Fair')| (data.cut)=='Premium' ]
result=data[data.cut.isin(['Good','Fair','Premium'])]
result
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72     Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [20307 rows x 10 columns]

# %%
#20
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
#21
data.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
#22

# %%
#23
new_data=data.drop(columns=data.select_dtypes(include=['object']))
new_data
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
#24
numeric_data=data.select_dtypes(include=['int','float'])
numeric_data
# Out:
#        carat  depth  table     x     y     z
# 0       0.23   61.5   55.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0  3.89  3.84  2.31
# 2       0.23   56.9   65.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  5.66  5.68  3.56
# 53938   0.86   61.0   58.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %%
#25
described_data=data.describe(include=['float','object'])
described_data
# Out:
#                carat    cut  color clarity         depth         table  \
# count   53940.000000  53940  53940   53940  53940.000000  53940.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  21551  11292   13065           NaN           NaN
# mean        0.797940    NaN    NaN     NaN     61.749405     57.457184
# std         0.474011    NaN    NaN     NaN      1.432621      2.234491
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         5.010000    NaN    NaN     NaN     79.000000     95.000000
#
#                    x             y             z
# count   53940.000000  53940.000000  53940.000000
# ...

# %%
#26
mean_data=data.mean()
mean_data
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
#27
data_mean=data.mean(axis=1)
data_mean
# Out:
# 0         64.727143
# 1         65.292857
# 2         65.651429
# 3         66.535714
# 4         66.864286
#             ...
# 53935    412.932857
# 53936    412.981429
# 53937    413.628571
# 53938    413.267143
# 53939    412.898571
# Length: 53940, dtype: float64

# %%
#28
cut_mean=data.groupby("cut").price.mean()
cut_mean
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
#29
cut_count=data.groupby("cut").price.count()
cut_max=data.groupby("cut").price.max()
cut_min=data.groupby("cut").price.min()
print(cut_count)
print(cut_max)
print(cut_min)
# Out:
# cut
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: price, dtype: int64
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64
# cut
# Fair         337
# Good         327
# Ideal        326
# Premium      326
# Very Good    336
# Name: price, dtype: int64

# %%
#30
import matplotlib.pyplot as plt

# %%
#31
aa=data["cut"].value_counts()
#aa=data.groupby("cut").count()

# %%
aa
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#32
#aa=data["cut"].value_counts(normalize=True)*100
aa= ((data["cut"].value_counts())/data["cut"].count())*100

# %%
aa
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: cut, dtype: float64

# %%
#33
unique_cut=data["cut"].unique()

# %%
unique_cut
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#34
#unique_cut_count=data.cut.unique().size
unique_cut_count=data.cut.nunique()
unique_cut_count
# Out:
# 5

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#35
crosstab_series= pd.crosstab(data.cut,data.clarity)
crosstab_series
# Out:
# clarity     I1    IF   SI1   SI2   VS1   VS2  VVS1  VVS2
# cut
# Fair       210     9   408   466   170   261    17    69
# Good        96    71  1560  1081   648   978   186   286
# Ideal      146  1212  4282  2598  3589  5071  2047  2606
# Premium    205   230  3575  2949  1989  3357   616   870
# Very Good   84   268  3240  2100  1775  2591   789  1235

# %%
#36
summary_stats=data["cut"].describe()

# %%
summary_stats
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
#37
plt.hist(data["carat"])
plt.show()

# %%
#38
unique_cut=data["cut"].unique()
aa=data["cut"].value_counts()
plt.bar(unique_cut,aa)
plt.show()

# %%
#39
boolean_data=data.isnull()
boolean_data
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
#40
missing_values=data.isnull().sum()
missing_values
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#41
drop_rows= data.dropna()
drop_rows
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#42
drop_rows_byclm= data.dropna(subset=['carat','cut'])
drop_rows_byclm
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#43
new_index=data.set_index('carat')
new_index
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
#44

# %%
#45
index_value=data["cut"].value_counts().index
index_value
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
#46
sort_by_values=data["cut"].value_counts().sort_values()

# %%
sort_by_values
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %%
sort_by_index=data["cut"].value_counts().sort_index()

# %%
sort_by_index
# Out:
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: cut, dtype: int64

# %%
#47
#volume=(data["x"]*data["y"]*data["z"]).groupby("cut").count()
volume=(data["x"]*data["y"]*data["z"])

# %%
volume
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Length: 53940, dtype: float64

# %%
#48
color_series=data['color']

# %%
color_series
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
new_data=pd.concat([data,color_series],axis=1)

# %%
new_data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       color
# 0         E
# 1         E
# ...

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#49
data.iloc[7]
# Out:
# carat           0.26
# cut        Very Good
# color              H
# clarity          SI1
# depth           61.9
# table             55
# price            337
# x               4.07
# y               4.11
# z               2.53
# Name: 7, dtype: object

# %%
#50
data.iloc[[0,5,7]]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53

# %%
#51
data.iloc[2:6,]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48

# %%
#52
data.iloc[0:3,[2,6]]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
#53
data.iloc[0:3,2:6]
# Out:
#   color clarity  depth  table
# 0     E     SI2   61.5   55.0
# 1     E     SI1   59.8   61.0
# 2     E     VS1   56.9   65.0

# %%
#55
data.iloc[[0,1],[0,3]]
# Out:
#    carat clarity
# 0   0.23     SI2
# 1   0.21     SI1

# %%
#56
data.iloc[0:4,1:4]
# Out:
#        cut color clarity
# 0    Ideal     E     SI2
# 1  Premium     E     SI1
# 2     Good     E     VS1
# 3  Premium     I     VS2

# %%
#57
data.iloc[0:4,]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63

# %%
#58
data.iloc[2:6,0:2]
# Out:
#    carat        cut
# 2   0.23       Good
# 3   0.29    Premium
# 4   0.31       Good
# 5   0.24  Very Good

# %%
#59
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#60
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 13.2 MB

# %%
#61

# %%
#62
data.sample(5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 46515   0.66      Ideal     H     SI1   60.9   55.0   1780  5.63  5.70  3.45
# 25417   2.01  Very Good     H     SI2   63.2   57.0  14150  8.02  7.97  5.05
# 21855   1.19      Ideal     G     VS1   62.4   54.0   9918  6.78  6.81  4.24
# 24406   1.14  Very Good     E      IF   63.3   57.0  12647  6.63  6.71  4.22
# 34933   0.23      Ideal     G     SI1   61.2   56.0    375  3.97  4.00  2.44

# %%
#63

# %%
#64
#data[data.duplicated('color')]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53933 rows x 10 columns]

# %%
#65
data.duplicated().sum()
# Out:
# 146
